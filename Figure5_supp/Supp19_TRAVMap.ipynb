# %%
import muon as mu
import pandas as pd
import anndata as ad
import matplotlib.pyplot as plt
import scanpy as sc
import numpy as np

# %%
sc.settings.figdir="../result/24.3.10_travmap_supp/"

# %%
travMap=mu.read_h5mu("../../important_processed_data/12.30_trajMap.h5mu")
# Out:
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/mudata/_core/mudata.py:491: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(

# %%
travMap.obs["Sample"]
# Out:
# Bmsc2019_Regev_b3_sep_Chondro                                                                 Bmsc2019_Regev_b3
# BmscEndosteal_Ono_Fgfr3CE_sep_Chondro                                                 BmscEndosteal_Ono_Fgfr3CE
# BmscEndosteal_Ono_Fgfr3CEp53cHet_sep_Chondro                                   BmscEndosteal_Ono_Fgfr3CEp53cHet
# BmscEndosteal_Ono_Fgfr3CEp53cKO_sep_Chondro                                     BmscEndosteal_Ono_Fgfr3CEp53cKO
# BmscEndosteal_Ono_Gas1CE_sep_Chondro                                                   BmscEndosteal_Ono_Gas1CE
#                                                                                       ...
# Metaphysis_Yang_4_sep_Fibroblast                                                              Metaphysis_Yang_4
# Metaphysis_Yang_sorted_sep_Fibroblast                                                    Metaphysis_Yang_sorted
# ...

# %%
meta=pd.read_csv("../../important_processed_data/10.26_wt_integrate_meta.csv",index_col=0)
sampleDf2=meta[["Sample","Project"]][meta["Sample"].isin(travMap.obs["Sample"])].drop_duplicates()
# Out:
# /tmp/ipykernel_1385416/4137157370.py:1: DtypeWarning: Columns (12,17,18,19,21,22,23,26,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta=pd.read_csv("../../important_processed_data/10.26_wt_integrate_meta.csv",index_col=0)

# %%
sampleDf2.index=sampleDf2["Sample"]

# %%
sampleDf2=sampleDf2.loc[travMap.obs["Sample"]]

# %%
travMap.obs["Project"]=np.array(sampleDf2['Project'])

# %%
corr=travMap["coor"]
expr=travMap["expr"]
peak=travMap["peak"]
TRAV=travMap["TRAV"]

# %%
sc.pl.umap(corr,color=["Lineage","Organ"],save="corr.pdf")
sc.pl.umap(expr,color=["Lineage","Organ"],save="expr.pdf")
sc.pl.umap(peak,color=["Lineage","Organ"],save="peak.pdf")
sc.pl.umap(TRAV,color=["Lineage","Organ"],save="TRAV.pdf")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapcorr.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapexpr.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ...

# %%
sc.pl.umap(travMap,color=["Project"],save="Project.pdf")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapProject.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(travMap,color=["Tissue"],save="Tissue.pdf",palette="tab20")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapTissue.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
travMap
# Out:
# MuData object with n_obs × n_vars = 121 × 52162
#   obs:	'Organ', 'Stage', 'Age', 'Tissue', 'Tissue.Specific.', 'Gene.type', 'Treatment', 'Age.In.Detail.', 'Machine', 'Origin', 'Sample', 'Lineage', 'Project'
#   uns:	'Age_colors', 'Lineage_colors', 'Machine_colors', 'Organ_colors', 'Tissue.Specific._colors', 'Tissue_colors', 'neighbors', 'umap', 'Project_colors'
#   obsm:	'X_umap'
#   obsp:	'connectivities', 'distances'
#   4 modalities
#     coor:	121 x 17312
#       obs:	'Organ', 'Stage', 'Age', 'Tissue', 'Tissue.Specific.', 'Gene.type', 'Treatment', 'Age.In.Detail.', 'Machine', 'Origin', 'Sample', 'Lineage', 'coor:mod_weight', 'expr:mod_weight', 'peak:mod_weight', 'TRAV:mod_weight', 'Age_OPC'
#       var:	'mean', 'std'
#       uns:	'Lineage_colors', 'neighbors', 'pca', 'umap', 'Organ_colors'
#       obsm:	'TrajMap_umap', 'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'raw'
#       obsp:	'connectivities', 'distances'
#     expr:	121 x 17312
# ...

# %%
sc.pl.umap(travMap,color=["Tissue.Specific."],save="Tissue.Specific.pdf",palette="tab20")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapTissue.Specific.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(travMap,color=["Machine"],save="Machine.pdf")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapMachine.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(travMap,color=["Treatment"],save="Treatment.pdf")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/umapTreatment.pdf
# /home/gilberthan/anaconda3/envs/scarches/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
TRAV.var_names
# Out:
# Index(['RAV1', 'RAV2', 'RAV3', 'RAV4', 'RAV5', 'RAV6', 'RAV7', 'RAV8', 'RAV9',
#        'RAV10',
#        ...
#        'RAV217', 'RAV218', 'RAV219', 'RAV220', 'RAV221', 'RAV222', 'RAV223',
#        'RAV224', 'RAV225', 'RAV226'],
#       dtype='object', length=226)

# %%
TRAV
# Out:
# AnnData object with n_obs × n_vars = 121 × 226
#     obs: 'Organ', 'Stage', 'Age', 'Tissue', 'Tissue.Specific.', 'Gene.type', 'Treatment', 'Age.In.Detail.', 'Machine', 'Origin', 'Sample', 'Lineage', 'coor:mod_weight', 'expr:mod_weight', 'peak:mod_weight', 'TRAV:mod_weight', 'Age_OPC'
#     var: 'mean', 'std'
#     uns: 'Age_OPC_colors', 'Age_colors', 'Lineage_colors', 'neighbors', 'pca', 'umap', 'Organ_colors'
#     obsm: 'TrajMap_umap', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'raw'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.embedding(TRAV,color=["RAV143"],save="RAV.pdf",layer="raw",basis="TrajMap_umap")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/TrajMap_umapRAV.pdf

# %%
sc.pl.embedding(expr,color=["Dusp10"],save="expr_Dusp10.pdf",layer="raw",basis="TrajMap_umap")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/TrajMap_umapexpr_Dusp10.pdf

# %%
sc.pl.embedding(corr,color=["Dusp10"],save="corr_Dusp10.pdf",layer="raw",basis="TrajMap_umap")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/TrajMap_umapcorr_Dusp10.pdf

# %%
sc.pl.embedding(peak,color=["Dusp10"],save="peak_Dusp10.pdf",layer="raw",basis="TrajMap_umap")
# Out:
# WARNING: saving figure to file ../result/24.3.10_travmap_supp/TrajMap_umappeak_Dusp10.pdf

# %%
TRAV.var_names
# Out:
# Index(['RAV1', 'RAV2', 'RAV3', 'RAV4', 'RAV5', 'RAV6', 'RAV7', 'RAV8', 'RAV9',
#        'RAV10',
#        ...
#        'RAV217', 'RAV218', 'RAV219', 'RAV220', 'RAV221', 'RAV222', 'RAV223',
#        'RAV224', 'RAV225', 'RAV226'],
#       dtype='object', length=226)
