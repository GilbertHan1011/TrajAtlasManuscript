# %%
import PyComplexHeatmap as pch
import pandas as pd
from pathlib import Path
import re
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import muon as mu
import cellrank as cr

# %%
cr.settings.figdir="../result/24.3.5_supp_traj_dotplot_validate/"
sc.settings.figdir="../result/24.3.5_supp_traj_dotplot_validate/"

# %%
sc._settings.settings._vector_friendly=True

# %%
dpt=sc.read("../../important_processed_data/11.16_dpt.h5ad")

# %%
lineageDpt=dpt.obs[[ 'lineage_chondro', 'lineage_laFibro', 'lineage_lepr', 'lineage_mesenchyme']]
crLineage=cr._utils.Lineage(np.array(lineageDpt)*dpt.obs[['pred_dpt']].values,
                            names=[ 'Chondro-OPCST', 'Fibro-OPCST', 'Lepr_BMSC-OPCST', 'Mesenchyme-OPCST'],
                            colors=["#3C5488B2", "#4DBBD5B2","#F39B7FB2","#00A087B2"])
dpt.obsm["to_terminal_states"]=crLineage

# %%
coorDf=pd.read_csv("../processed_data/12.9_trajMap/12.9_coorDf.csv",index_col=0)
peakDf=pd.read_csv("../processed_data/12.9_trajMap/12.9_maxDf.csv",index_col=0)
exprDf=pd.read_csv("../processed_data/12.9_trajMap/12.9_sumDf.csv",index_col=0)

# %%
coorDf_sqrt = np.where(coorDf >= 0, np.sqrt(coorDf), -np.sqrt(-coorDf))
coorDf_sqrt=pd.DataFrame(coorDf_sqrt)
coorDf_sqrt.columns=coorDf.columns
coorDf_sqrt.index=coorDf.index
scaled_df2 = exprDf.apply(lambda row: (row) / (row.max()), axis=1)

# %%
selectSample=['BmscTime_Zhong_1.5M',
              'BmscTime_Zhong_16M',
              'BmscTime_Zhong_1M',
              'BmscTime_Zhong_3M']

# %%
dptSelect=dpt[dpt.obs["Sample"].isin(selectSample)]

# %%
dptSelect=dptSelect[dptSelect.obs["lineage_lepr"]]

# %%
ageCategory= pd.get_dummies(dptSelect.obs['Age.In.Detail.'])

# %%
crLineage=cr._utils.Lineage(np.array(ageCategory)*dptSelect.obs[['pred_dpt']].values,
                            names=ageCategory.columns,
                            colors=["#3C5488B2", "#4DBBD5B2","#F39B7FB2","#00A087B2"])
dptSelect.obsm["to_terminal_states"]=crLineage

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Lepr"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Lepr.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Runx2"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Runx2.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Postn"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Postn.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Sost"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Sost.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Adipoq"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Adipoq.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Aspn"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Aspn.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dptSelect)
cr.pl.gene_trends(
    dptSelect,
    model=model,
    data_key="X",
    genes=["Sp7"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,save="Lepr_age_Sp7.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
selectSample=set(selectSample)

# %%
dptSelect.obs['Age.In.Detail.']
# Out:
# Unnamed: 0
# BmscTime_Zhong_1M_AAACCTGCATCCGGGT_1-0-2      1M
# BmscTime_Zhong_1M_AAACCTGGTATGGTTC_1-0-2      1M
# BmscTime_Zhong_1M_AAACCTGGTTGTCTTT_1-0-2      1M
# BmscTime_Zhong_1M_AAACCTGTCACAATGC_1-0-2      1M
# BmscTime_Zhong_1M_AAACCTGTCCTATGTT_1-0-2      1M
#                                             ...
# BmscTime_Zhong_16M_TTTGTTGGTCTACTGA_4-0-2    16M
# BmscTime_Zhong_16M_TTTGTTGGTGATAGTA_4-0-2    16M
# BmscTime_Zhong_16M_TTTGTTGTCACTGTTT_4-0-2    16M
# BmscTime_Zhong_16M_TTTGTTGTCAGCACCG_4-0-2    16M
# BmscTime_Zhong_16M_TTTGTTGTCTCGTCAC_4-0-2    16M
# Name: Age.In.Detail., Length: 9246, dtype: category
# Categories (4, object): ['1.5M', '1M', '3M', '16M']

# %%
mesSampleFile = ["../processed_data/12.12_TRAV/cpmList/lepr/" + sample + ".csv" for sample in selectSample]

# %%
mesDict={}
for i in range(len(mesSampleFile)):
    fileName=mesSampleFile[i]
    mesName=selectSample[i]
    hm=pd.read_csv(fileName)
    hmSelect=hm[dpt.var_names=="Aspn"]
    mesDict[mesName]=hmSelect

# %%
result_df = pd.concat(mesDict.values())

# %%
result_df=result_df.iloc[:,1:101]

# %%
result_df.index=selectSample

# %%
pch.ClusterMapPlotter(result_df,col_cluster=False,vmax=100,show_rownames=True,)
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm

# %%
mesDict={}
for i in range(len(mesSampleFile)):
    fileName=mesSampleFile[i]
    mesName=selectSample[i]
    hm=pd.read_csv(fileName)
    hmSelect=hm[dpt.var_names=="Lepr"]
    mesDict[mesName]=hmSelect

# %%
result_df = pd.concat(mesDict.values())

# %%
result_df=result_df.iloc[:,1:101]

# %%
result_df.index=selectSample

# %%
pch.ClusterMapPlotter(result_df,col_cluster=False,vmax=300,show_rownames=True,)
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 7.5 mm

# %%
sc.pl.draw_graph(dptSelect,color="Lepr",use_raw=False,save="Lepr")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faLepr.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Adipoq",use_raw=False,save="Adipoq")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faAdipoq.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Aspn",use_raw=False,save="Aspn")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faAspn.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Postn",use_raw=False,save="Postn")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faPostn.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Sost",use_raw=False,save="Sost")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faSost.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Runx2",use_raw=False,save="Runx2")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faRunx2.pdf

# %%
sc.pl.draw_graph(dptSelect,color="Sp7",use_raw=False,save="Sp7")
# Out:
# WARNING: saving figure to file ../result/24.3.5_supp_traj_dotplot_validate/draw_graph_faSp7.pdf

# %%
set(dpt.obs["Sample"])
# Out:
# {'Ablation_Matsushita_abl14',
#  'Ablation_Matsushita_abl7con1',
#  'Ablation_Matsushita_abl7con2',
#  'Ablation_Matsushita_cxcl1',
#  'Ablation_Matsushita_cxcl2',
#  'Ablation_Matsushita_treat1',
#  'Ablation_Matsushita_treat2',
#  'Bmsc2019_Regev_b1',
#  'Bmsc2019_Regev_b2',
#  'Bmsc2019_Regev_b3',
#  'Bmsc2019_Regev_b4',
#  'Bmsc2019_Regev_bm1',
#  'Bmsc2019_Regev_bm2',
#  'Bmsc2019_Regev_bm3',
#  'Bmsc2019_Regev_bm4',
#  'Bmsc2019_Regev_samp1',
#  'Bmsc2019_Regev_samp2',
#  'Bmsc2019_Regev_samp3',
#  'Bmsc2019_Regev_samp4',
#  'Bmsc2019_Regev_samp5',
#  'Bmsc2019_Regev_samp6',
#  'BmscChondro_Long',
#  'BmscEndosteal_Ono_Fgfr3CE',
#  'BmscEndosteal_Ono_Fgfr3CEp53cHet',
#  'BmscEndosteal_Ono_Fgfr3CEp53cKO',
#  'BmscEndosteal_Ono_Gas1CE',
#  'BmscEndosteal_Ono_Prrx1cre18M',
#  'BmscEndosteal_Ono_Prrx1creP21',
#  'BmscEndosteal_Ono_Prrx1creP21multiome',
#  'BmscSpecification_Kishor_1',
#  'BmscSpecification_Kishor_2',
#  'BmscSpecification_Kishor_3',
# ...

# %%
def makeLong2(gene,sampleIndex):
    selectCoor=coorDf_sqrt.loc[gene]
    selectExpr=scaled_df2.loc[gene]
    selectPeak=peakDf.loc[gene]
    selectCoor=selectCoor.iloc[:,sampleIndex]
    selectExpr=selectExpr.iloc[:,sampleIndex]
    selectPeak=selectPeak.iloc[:,sampleIndex]
    coorLong=selectCoor.stack().reset_index(name="Coor")
    exprLong=selectExpr.stack().reset_index(name="Expr")
    peakLong=selectPeak.stack().reset_index(name="Peak")
    peakLong['Stage']=peakLong.Peak.apply(lambda x:'End' if x>=7 else 'Middle' if x >= 3 else 'Start')
    combineDf=coorLong
    combineDf["Expr"]=exprLong['Expr']
    combineDf["Peak"]=peakLong['Stage']
    return(combineDf)

# %%
coorDf_sqrt.columns[40:50]
# Out:
# Index(['BmscEndosteal_Ono_Prrx1cre18M_sep_Lepr_BMSC',
#        'BmscEndosteal_Ono_Prrx1creP21_sep_Lepr_BMSC',
#        'BmscEndosteal_Ono_Prrx1creP21multiome_sep_Lepr_BMSC',
#        'BmscSpecification_Kishor_1_sep_Lepr_BMSC',
#        'BmscSpecification_Kishor_2_sep_Lepr_BMSC',
#        'BmscSpecification_Kishor_3_sep_Lepr_BMSC',
#        'BmscSpecification_Kishor_4_sep_Lepr_BMSC',
#        'BmscTime_Zhong_1.5M_sep_Lepr_BMSC', 'BmscTime_Zhong_16M_sep_Lepr_BMSC',
#        'BmscTime_Zhong_1M_sep_Lepr_BMSC'],
#       dtype='object')

# %%
selectLineage=[sample + "_sep_Lepr_BMSC" for sample in selectSample]

# %%
sampleIndex=np.where(coorDf_sqrt.columns.isin(selectLineage))[0]

# %%
dotDf=makeLong2(["Lepr","Runx2","Postn","Sost","Aspn"],sampleIndex)

# %%
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=40,
                              show_rownames=True,show_colnames=True,spines=True)
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Lepr"],sampleIndex)

# %%
dotDf1
# Out:
#                              level_0                            level_1
# typing.Literal[<no_default>]
# 0                               Lepr  BmscTime_Zhong_1.5M_sep_Lepr_BMSC  \
# 1                               Lepr   BmscTime_Zhong_16M_sep_Lepr_BMSC
# 2                               Lepr    BmscTime_Zhong_1M_sep_Lepr_BMSC
# 3                               Lepr    BmscTime_Zhong_3M_sep_Lepr_BMSC
#
#                                   Coor      Expr   Peak
# typing.Literal[<no_default>]
# 0                            -0.881762  0.671054  Start
# 1                            -0.914952  0.922935  Start
# 2                            -0.856941  0.520446  Start
# 3                            -0.839647  0.566677  Start

# %%
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=40,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/lepr_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Runx2"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=40,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Runx2_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Sp7"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Sp7_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Aspn"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Aspn_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Aspn"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Aspn_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Adipoq"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Adipoq_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Postn"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Postn_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol
# Incresing ncol
# More than 3 cols is not supported
# Legend too long, generating a new column..

# %%
dotDf1=makeLong2(["Sost"],sampleIndex)
plt.figure(figsize=(2,2))
cm = pch.DotClustermapPlotter(dotDf1,x='level_0',y='level_1',value='Coor',c='Coor',hue='Peak',s="Expr",
                               marker={'Start':'o','Middle':'D','End':'s'},row_dendrogram=False,ratio=60,row_cluster=False,col_cluster=False,
                              show_rownames=True,show_colnames=True,spines=True)
plt.savefig("../result/24.3.5_supp_traj_dotplot_validate/Sost_dot.pdf")
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# ...
# Plotting legends..
# Estimated legend width: 12.172222222222222 mm
# Incresing ncol

# %%
dpt.obs["Stage"]
# Out:
# Unnamed: 0
# Suture2021_Farmer_E17_AAACCTGCAGACTCGC-1_1-0    Development
# Suture2021_Farmer_E17_AAACCTGGTGGTCTCG-1_1-0    Development
# Suture2021_Farmer_E17_AAACCTGTCACCACCT-1_1-0    Development
# Suture2021_Farmer_E17_AAAGATGAGGGAACGG-1_1-0    Development
# Suture2021_Farmer_E17_AAAGTAGTCGGAGCAA-1_1-0    Development
#                                                    ...
# TTTGACTGTATTTCCT-1_5-1-2                        Development
# TTTGACTGTTGCATTG-1_5-1-2                        Development
# TTTGACTTCTTGGGCG-1_5-1-2                        Development
# TTTGGAGCAGCGACAA-1_5-1-2                        Development
# TTTGGTTCACTACTTT-1_5-1-2                        Development
# Name: Stage, Length: 166204, dtype: category
# Categories (3, object): ['Development', 'Injury(Regeneration)', 'Steady']

# %%
dpt.obs["Young_Adult"]=dpt.obs["Stage"]

# %%
dpt=dpt[dpt.obs["lineage_lepr"]]

# %%
dpt.obs["Young_Adult"]=dpt.obs["Young_Adult"].astype("str")
# Out:
# /tmp/ipykernel_2615262/3903303646.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   dpt.obs["Young_Adult"]=dpt.obs["Young_Adult"].astype("str")

# %%
dpt.obs["Young_Adult"][dpt.obs["Age"].isin([ 'Postnatal', 'Young Adult'])]="Young"
dpt.obs["Young_Adult"][dpt.obs["Age"].isin([ 'Adult', 'Old'])]="Adult"

# %%
youngCategory= pd.get_dummies(dpt.obs['Young_Adult'])

# %%
crLineage=cr._utils.Lineage(np.array(youngCategory)*dpt.obs[['pred_dpt']].values,
                            names=youngCategory.columns,
                            colors=["#3C5488B2", "#4DBBD5B2"])
dpt.obsm["to_terminal_states"]=crLineage

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Vcan"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Vcan"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Vcan.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Psmd2"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Psmd2.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Dad1"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Dad1.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Agt"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Agt.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Smad7"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Smad7.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Hmox1"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Hmox1.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Lifr"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Lifr.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]

# %%
model = cr.models.GAM(dpt)
cr.pl.gene_trends(
    dpt,
    model=model,
    data_key="X",
    genes=["Fbln1"],
    ncols=3,
    time_key="pred_dpt",
    same_plot=True,
    hide_cells=True,
    figsize=(5, 4),
    n_test_points=200,n_jobs=-1,
    save="Fbln1.pdf"
)
# Out:
#   0%|          | 0/1 [00:00<?, ?gene/s]
