# %%
import scanpy as sc
import pandas as pd

# %%
sc.settings.figdir="../result/9.10_rejection/"

# %%
reflatent=sc.read("../../important_processed_data/8.29_reflatent.h5ad")

# %%
wt_meta=pd.read_csv("../../important_processed_data/5.22_wt_integrate_meta.csv")
# Out:
# /tmp/ipykernel_3687443/3963972681.py:1: DtypeWarning: Columns (17,18,19,21,22,23,26,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   wt_meta=pd.read_csv("../../important_processed_data/5.22_wt_integrate_meta.csv")

# %%
reflatent.obs["Core_data"]="Extand"

# %%
reflatent.obs["Core_data"][reflatent.obs["Sample"].isin(wt_meta["Sample"])]="Core"
# Out:
# /tmp/ipykernel_3687443/3377348948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflatent.obs["Core_data"][reflatent.obs["Sample"].isin(wt_meta["Sample"])]="Core"

# %%
reflatent.obs["Sample"].isin(wt_meta["Sample"])
# Out:
# Suture2021_Farmer_E17_AAACCTGCAGACTCGC-1_1-0_1_1     True
# Suture2021_Farmer_E17_AAACCTGGTGCGGTAA-1_1-0_1_1     True
# Suture2021_Farmer_E17_AAACCTGGTGGTCTCG-1_1-0_1_1     True
# Suture2021_Farmer_E17_AAACCTGTCACCACCT-1_1-0_1_1     True
# Suture2021_Farmer_E17_AAACCTGTCGTTACGA-1_1-0_1_1     True
#                                                     ...
# TTTGTTGAGGTGATAT-1_8                                False
# TTTGTTGAGTCTTCCC-1_8                                False
# TTTGTTGGTCCACACG-1_8                                False
# TTTGTTGTCACTACGA-1_8                                False
# TTTGTTGTCCGGGACT-1_8                                False
# Name: Sample, Length: 781397, dtype: bool

# %%
reflatent.obs["Core_data"]
# Out:
# Suture2021_Farmer_E17_AAACCTGCAGACTCGC-1_1-0_1_1      Core
# Suture2021_Farmer_E17_AAACCTGGTGCGGTAA-1_1-0_1_1      Core
# Suture2021_Farmer_E17_AAACCTGGTGGTCTCG-1_1-0_1_1      Core
# Suture2021_Farmer_E17_AAACCTGTCACCACCT-1_1-0_1_1      Core
# Suture2021_Farmer_E17_AAACCTGTCGTTACGA-1_1-0_1_1      Core
#                                                      ...
# TTTGTTGAGGTGATAT-1_8                                Extand
# TTTGTTGAGTCTTCCC-1_8                                Extand
# TTTGTTGGTCCACACG-1_8                                Extand
# TTTGTTGTCACTACGA-1_8                                Extand
# TTTGTTGTCCGGGACT-1_8                                Extand
# Name: Core_data, Length: 781397, dtype: category
# Categories (2, object): ['Core', 'Extand']

# %%
sc.pl.umap(reflatent,color="Core_data",size=1,groups="Core",save="coreData.pdf")
# Out:
# WARNING: saving figure to file ../result/9.10_rejection/umapcoreData.pdf
# /home/gilberthan/anaconda3/envs/scvelo/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
reflatent.obs["Core"]

# %%
reflatent.obs["C7_anno"]="Extand"

# %%
reflatent.obs["C7_anno"][reflatent.obs["Sample"].isin(wt_meta["Sample"])]=wt_meta["C7_named"]
# Out:
# /tmp/ipykernel_3687443/456593023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reflatent.obs["C7_anno"][reflatent.obs["Sample"].isin(wt_meta["Sample"])]=wt_meta["C7_named"]

# %%
sc.pl.umap(reflatent,color="C7_anno",size=1,groups="Core",save="C7_anno.pdf")
# Out:
# WARNING: saving figure to file ../result/9.10_rejection/umapC7_anno.pdf
# /home/gilberthan/anaconda3/envs/scvelo/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
reflatent.obs["C7_anno"][reflatent.obs["Sample"].isin(wt_meta["Sample"])]
# Out:
# Suture2021_Farmer_E17_AAACCTGCAGACTCGC-1_1-0_1_1    NaN
# Suture2021_Farmer_E17_AAACCTGGTGCGGTAA-1_1-0_1_1    NaN
# Suture2021_Farmer_E17_AAACCTGGTGGTCTCG-1_1-0_1_1    NaN
# Suture2021_Farmer_E17_AAACCTGTCACCACCT-1_1-0_1_1    NaN
# Suture2021_Farmer_E17_AAACCTGTCGTTACGA-1_1-0_1_1    NaN
#                                                    ...
# TTTGACTGTATTTCCT-1_5-1-2_1_1                        NaN
# TTTGACTGTTGCATTG-1_5-1-2_1_1                        NaN
# TTTGACTTCTTGGGCG-1_5-1-2_1_1                        NaN
# TTTGGAGCAGCGACAA-1_5-1-2_1_1                        NaN
# TTTGGTTCACTACTTT-1_5-1-2_1_1                        NaN
# Name: C7_anno, Length: 272369, dtype: category
# Categories (1, object): ['Extand']

# %%
reflatent.obs.loc[reflatent.obs['Sample'].isin(wt_meta['Sample']), 'C7_anno']=wt_meta["C7_named"].values

# %%
wt_meta["C7_named"].unique()
# Out:
# array(['MSC', 'Ly6a+ MSC', 'Ob', 'Lepr+ BMSC', 'Fibroblast', 'Chondro',
#        'Pericyte'], dtype=object)

# %%
sc.pl.umap(reflatent,color="C7_anno",size=1,groups=['MSC', 'Ly6a+ MSC', 'Ob', 'Lepr+ BMSC', 'Fibroblast', 'Chondro',
       'Pericyte'],save="C7_anno.pdf")
# Out:
# WARNING: saving figure to file ../result/9.10_rejection/umapC7_anno.pdf
# /home/gilberthan/anaconda3/envs/scvelo/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
reflatent.obs["C19_anno"]="Extand"

# %%
reflatent.obs.loc[reflatent.obs['Sample'].isin(wt_meta['Sample']), 'C19_anno']=wt_meta["C19_named"].values

# %%
sc.pl.umap(reflatent,color="C19_anno",size=1,
           groups=['Late.MSC', 'Ly6a+ MSC', 'Ob', 'Lepr+ BMSC', 'Pre-ob', 'Meninges',
       'Early.MSC', 'Middle.MSC', 'Fibro', 'HC', 'Pericyte', 'Irx1+ MSC',
       'CPC', 'Mature Chondro', 'Hmmr+ CPC', 'Col1a1.Chondro',
       'Tex14+ HC', 'Cyp26a1.Chondro',"Low quality"],save="C19_anno.pdf")
# Out:
# WARNING: saving figure to file ../result/9.10_rejection/umapC19_anno.pdf
# /home/gilberthan/anaconda3/envs/scvelo/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
wt_meta["C19_named"].unique()
# Out:
# array(['Late.MSC', 'Ly6a+ MSC', 'Ob', 'Lepr+ BMSC', 'Pre-ob', 'Meninges',
#        'Early.MSC', 'Middle.MSC', 'Fibro', 'HC', 'Pericyte', 'Irx1+ MSC',
#        'CPC', 'Mature Chondro', 'Hmmr+ CPC', 'Col1a1.Chondro',
#        'Tex14+ HC', 'Cyp26a1.Chondro'], dtype=object)

# %%
reflatent.obs["C36_anno"]="Extand"

# %%
reflatent.obs.loc[reflatent.obs['Sample'].isin(wt_meta['Sample']), 'C36_anno']=wt_meta["C36_named"].values

# %%
import numpy as np

# %%
sc.pl.umap(reflatent,color="C36_anno",size=1,
           groups=['Alcam.Late.MSC', 'Col6a6.Ly6a+ MSC', 'Col22a1.Ob',
       'Col6a5.Lepr+ BMSC', 'Dapk2.Pre-ob', 'Wnt2.Late.MSC', 'Meninges',
       'Pclaf.Early.MSC', 'Gas2.Middle.MSC', 'Pax3.Middle.MSC',
       'Aspn.Fibro', 'Bglap3.Ob', 'Lipc.HC', 'Adipoq.Lepr+ BMSC',
       'Ppbp+ BMSC', 'Pericyte', 'Ostn.Pre-ob', 'Irx1+ MSC',
       'A2m+ Chondro', 'Ucma.CPC', 'Otos.Pre-ob', 'Il17b.Mature Chondro',
       'Sfrp4.Late.MSC', 'Hmmr+ CPC', 'Pde11a.HC', 'Prg4.CPC',
       'Clic5.Ly6a+ MSC', 'Kcnk2.Lepr+ BMSC', 'Col1a1.Chondro',
       'Hoxa13.Early.MSC', 'Slurp1.Fibro', 'Ihh.Mature Chondro',
       'Aldh1a3+ HC', 'Ffar4+ HC', 'Cyp26a1.Chondro'],save="C36_anno.pdf")
# Out:
# WARNING: saving figure to file ../result/9.10_rejection/umapC36_anno.pdf
# /home/gilberthan/anaconda3/envs/scvelo/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
np.array(wt_meta["C36_named"].unique())
# Out:
# array(['Alcam.Late.MSC', 'Col6a6.Ly6a+ MSC', 'Col22a1.Ob',
#        'Col6a5.Lepr+ BMSC', 'Dapk2.Pre-ob', 'Wnt2.Late.MSC', 'Meninges',
#        'Pclaf.Early.MSC', 'Gas2.Middle.MSC', 'Pax3.Middle.MSC',
#        'Aspn.Fibro', 'Bglap3.Ob', 'Lipc.HC', 'Adipoq.Lepr+ BMSC',
#        'Ppbp+ BMSC', 'Pericyte', 'Ostn.Pre-ob', 'Irx1+ MSC',
#        'A2m+ Chondro', 'Ucma.CPC', 'Otos.Pre-ob', 'Il17b.Mature Chondro',
#        'Sfrp4.Late.MSC', 'Hmmr+ CPC', 'Pde11a.HC', 'Prg4.CPC',
#        'Clic5.Ly6a+ MSC', 'Kcnk2.Lepr+ BMSC', 'Col1a1.Chondro',
#        'Hoxa13.Early.MSC', 'Slurp1.Fibro', 'Ihh.Mature Chondro',
#        'Aldh1a3+ HC', 'Ffar4+ HC', 'Cyp26a1.Chondro'], dtype=object)
